# %% [markdown]
# ### TSMC-I: Análisis de datos en Python

# %% [markdown]
# Utilice la los datos del archivo *nacimientos_2022* del repositorio en Github y obtenga lo siguiente:
#
# * El número total de nacimientos en 2022
# * El número total de nacimientos en la región centro-sur
# * Elabore un dataframe que contenga el número de nacimientos de mujeres por región.

# %%
import pandas as pd

# %%
df = pd.read_csv('nacimientos_2022.csv')
df
# Out:
#                    Estado Abreviatura    Regiones  Mujeres  Hombres  No_esp  \
# 0          Aguascalientes          AG     Noreste    10410    10796       0
# 1         Baja California          BC    Noroeste    29944    30732       0
# 2     Baja California Sur          BS    Noroeste     5396     5732       0
# 3                Campeche          CM     Sureste     6841     7049       0
# 4    Coahuila de Zaragoza          CO     Noreste    22835    23471       0
# 5                  Colima          CL   Occidente     4404     4721       0
# 6                 Chiapas          CS     Sureste    72880    78684       0
# 7               Chihuahua          CH    Noroeste    25458    26231       0
# 8                    CDMX          CX  Centro-Sur    43610    44789       0
# 9                 Durango          DG    Noroeste    14859    15248       0
# 10             Guanajuato          GT     Noreste    48392    49754       0
# ...

# %% [markdown]
# * El número total de nacimientos en 2022

# %%
total = df['Total'].sum()
print(total)
# Out:
# 1880718

# %% [markdown]
# * El número total de nacimientos en la región centro-sur.

# %%
CentroSur_df = df[df['Regiones'] == 'Centro-Sur']

# %%
CentroSur_df
# Out:
#        Estado Abreviatura    Regiones  Mujeres  Hombres  No_esp   Total
# 8        CDMX          CX  Centro-Sur    43610    44789       0   88399
# 11   Guerrero          GR  Centro-Sur    35840    36055       0   71895
# 16    Morelos          MO  Centro-Sur    13088    13845       0   26933
# 20     Puebla          PU  Centro-Sur    55168    57153       0  112321
# 28   Tlaxcala          TL  Centro-Sur     9653     9964       1   19618

# %%
NacimientosCS = CentroSur_df['Total'].sum()
print(NacimientosCS)
# Out:
# 319166

# %% [markdown]
# * Elabore un dataframe que contenga el número de nacimientos de mujeres por región

# %%
#Hacemos una copia del df original para no afectarlo
NacimientoMujeres = df.copy()
NacimientoMujeres.set_index("Estado")
# Out:
#                      Abreviatura    Regiones  Mujeres  Hombres  No_esp   Total
# Estado
# Aguascalientes                AG     Noreste    10410    10796       0   21206
# Baja California               BC    Noroeste    29944    30732       0   60676
# Baja California Sur           BS    Noroeste     5396     5732       0   11128
# Campeche                      CM     Sureste     6841     7049       0   13890
# Coahuila de Zaragoza          CO     Noreste    22835    23471       0   46306
# Colima                        CL   Occidente     4404     4721       0    9125
# Chiapas                       CS     Sureste    72880    78684       0  151564
# Chihuahua                     CH    Noroeste    25458    26231       0   51689
# CDMX                          CX  Centro-Sur    43610    44789       0   88399
# Durango                       DG    Noroeste    14859    15248       0   30107
# Guanajuato                    GT     Noreste    48392    49754       0   98146
# ...

# %%
N
